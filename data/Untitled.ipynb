# %%
##  Libarraies
import pandas as pd
import numpy as np
from prophet import Prophet
import plotly.express as px

# %%
pip install prophet
pip install dash plotly
pip install pandas numpy scikit-learn prophet

# %%
pip install statsmodels
# Out:
# ...
#
# ...

# %%
dates = pd.date_range(start='2024-01-01', periods=720)
sales = np.random.poisson(lam=30, size=720) + 10 * np.sin(np.arange(720) * 2 * np.pi / 7)
sales1 = np.random.poisson(lam=30, size=720)
df = pd.DataFrame({'date': dates, 'sales': sales})
df1= pd.DataFrame({'date': dates, 'sales': sales1})

# %%
df.head()
# Out:
#         date      sales
# 0 2024-01-01  35.000000
# 1 2024-01-02  42.818315
# 2 2024-01-03  43.749279
# 3 2024-01-04  43.338837
# 4 2024-01-05  18.661163

# %%
df.describe()
# Out:
#                       date       sales
# count                  720  720.000000
# mean   2024-12-25 12:00:00   29.888637
# min    2024-01-01 00:00:00    5.250721
# 25%    2024-06-28 18:00:00   23.250721
# 50%    2024-12-25 12:00:00   29.338837
# 75%    2025-06-23 06:00:00   36.766538
# max    2025-12-20 00:00:00   56.749279
# std                    NaN    8.616515

# %%
fig = px.line(df, x=df['date'], y=df['sales'], title='Daily Sales Trend')
fig.show()
